# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('IRIS.csv')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df_copy = df

# %%
df_copy['species'] = le.fit_transform(df_copy['species'])
df_copy.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0

# %%
df_copy['species'].value_counts()
# Out:
# species
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
df = df_copy

# %%
colors = ['red','blue','yellow']
species = [0,1,2]

# %%
for i in range(3):
    x = df[df['species']==species[i]]
    plt.scatter(x['sepal_length'],x['sepal_width'],color=colors[i],label = species[i])
    plt.xlabel('sepal_length')
    plt.ylabel('sepal_width')
    plt.legend()

# %%
for i in range(3):
    x = df[df['species']==species[i]]
    plt.scatter(x['sepal_length'],x['petal_length'],color=colors[i],label = species[i])
    plt.xlabel('sepal_length')
    plt.ylabel('petal_length')
    plt.legend()

# %%
for i in range(3):
    x = df[df['species']==species[i]]
    plt.scatter(x['petal_width'],x['petal_length'],color=colors[i],label = species[i])
    plt.xlabel('petal_width')
    plt.ylabel('petal_length')
    plt.legend()

# %%
for i in range(3):
    x = df[df['species']==species[i]]
    plt.scatter(x['petal_width'],x['sepal_width'],color=colors[i],label = species[i])
    plt.xlabel('petal_width')
    plt.ylabel('sepal_width')
    plt.legend()

# %%
X1 = df.drop(['species','sepal_length','petal_length'],axis=1)
y1 = df['species']
from sklearn.model_selection import train_test_split
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.3,random_state=2,stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X1_train,y1_train)
# Out:
# LogisticRegression()

# %%
prediction = model.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
score = accuracy_score(y1_test,prediction)
print(score)
cm = confusion_matrix()
